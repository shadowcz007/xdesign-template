# %%
hs=['31省区市新增62例本土确诊', '中国抗疫压力几何?专家解读', '新一季“太空生活”剧透来了', '江苏新增40例本土确诊:扬州36例', '监狱拍视频介绍高墙内的世界', '南京疫情传播链已涉29地多人被问责', '湖南一家16口超级大家庭居家隔离', '拒回国的白俄女运动员飞抵波兰', '英国跳水名将戴利看台上为狗织毛衣', '全国上半年离婚大数据:河南最多']

# %%
'\n'.join(hs)
# Out:
# '31省区市新增62例本土确诊\n中国抗疫压力几何?专家解读\n新一季“太空生活”剧透来了\n江苏新增40例本土确诊:扬州36例\n监狱拍视频介绍高墙内的世界\n南京疫情传播链已涉29地多人被问责\n湖南一家16口超级大家庭居家隔离\n拒回国的白俄女运动员飞抵波兰\n英国跳水名将戴利看台上为狗织毛衣\n全国上半年离婚大数据:河南最多'

# %%
import numpy as np
import cv2
img = cv2.imread('test.jpg')
Z = img.reshape((-1,3))
# convert to np.float32
Z = np.float32(Z)
# define criteria, number of clusters(K) and apply kmeans()
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 2
ret,label,center=cv2.kmeans(Z,K,None,criteria,10,cv2.KMEANS_RANDOM_CENTERS)
# Now convert back into uint8, and make original image
center = np.uint8(center)
res = center[label.flatten()]
res2 = res.reshape((img.shape))

# %%
from matplotlib import pyplot as plt

# #opencv读取图片，默认是 BGR ,不是rgb
# img=cv2.imread('img/img_94.png',cv2.IMREAD_COLOR)
img=cv2.cvtColor(res2, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
center
# Out:
# array([[198, 129,  16],
#        [229, 219, 227],
#        [241, 164,  72],
#        [ 92,  79,  40],
#        [250, 251, 254],
#        [158, 152, 148],
#        [118, 151, 249],
#        [ 54,  85, 245]], dtype=uint8)

# %%
# !pip install mmcq.py

# %%
from mmcq import get_palette
from PIL import Image, ImageDraw

# create an image
out = Image.new("RGB", (1000, 1000), (255, 255, 255))
d = ImageDraw.Draw(out)

with get_palette('test.jpg', 8) as palette:
    for i, color in enumerate(palette):
        d.rectangle((((i - 1) * 100, 0), (i * 100, 100)), fill=color)

out.show()

# %%
palettes=[]
with get_palette('test.png', 8) as palette:
    for p in palette:
        palettes.append([p[0],p[1],p[2]])
palettes
# Out:
# [[61, 33, 43],
#  [198, 180, 190],
#  [164, 98, 78],
#  [192, 15, 44],
#  [156, 113, 123],
#  [122, 32, 37],
#  [185, 55, 86]]

# %%
xs=['31省区市新增62例本土确诊', {'title': '31省区市新增62例本土确诊', 'score': '500万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//2818645318b88b0f1e6d5c6a073dd43d?x-bce-process=image/resize,m_fill,w_732,h_272'}, '女子10米跳台决赛', {'title': '女子10米跳台决赛', 'score': '468万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//bf6522444121bc8bf9afc968135414a2?x-bce-process=image/resize,m_fill,w_732,h_272'}, {'title': '女子10米跳台决赛', 'score': '468万', 'imgurl': 'https://ss0.baidu.com/6ONWsjip0QIZ8tyhnq/it/u=3310461438,2025055068&fm=179&app=35&f=GIF?w=124&h=32&s=EEE3A256EC4383301C9B9FFA0300D03D'}, '全红婵惊艳一跳裁判一致打满分', {'title': '全红婵惊艳一跳裁判一致打满分', 'score': '460万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//0c6a1466b0751186ddf4d04ae71cb971?x-bce-process=image/resize,m_fill,w_732,h_272'}, '监狱拍视频介绍高墙内的世界', {'title': '监狱拍视频介绍高墙内的世界', 'score': '445万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//dff7d35068d63af27cb5ae8d7874c3ff?x-bce-process=image/resize,m_fill,w_732,h_272'}, '美媒边说奖牌不重要边嘲讽印度', {'title': '美媒边说奖牌不重要边嘲讽印度', 'score': '436万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//b2b3c3c11da9e7d53c7a403b25dc5fc2?x-bce-process=image/resize,m_fill,w_732,h_272'}, '苏炳添谢震业太好笑了', {'title': '苏炳添谢震业太好笑了', 'score': '421万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//a6b7bfdb225a16c9825468a8337401e5?x-bce-process=image/resize,m_fill,w_732,h_272'}, '湖南一家16口超级大家庭居家隔离', {'title': '湖南一家16口超级大家庭居家隔离', 'score': '417万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//3931ba98db2119526c6f28dacd4f27e8?x-bce-process=image/resize,m_fill,w_732,h_272'}, '呼伦贝尔市报告1例本土确诊病例', {'title': '呼伦贝尔市报告1例本土确诊病例', 'score': '409万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//2818645318b88b0f1e6d5c6a073dd43d?x-bce-process=image/resize,m_fill,w_732,h_272'}, '外交部回应美国务院批准对台军售', {'title': '外交部回应美国务院批准对台军售', 'score': '398万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//3ae25885178497fc6d03238270342d79?x-bce-process=image/resize,m_fill,w_732,h_272'}, '全国上半年离婚大数据:河南最多', {'title': '全国上半年离婚大数据:河南最多', 'score': '381万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//98882b33a040f97045fc0cec4dd68458?x-bce-process=image/resize,m_fill,w_732,h_272'}]
for x in xs:
    print(x)
# Out:
# 31省区市新增62例本土确诊
# {'title': '31省区市新增62例本土确诊', 'score': '500万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//2818645318b88b0f1e6d5c6a073dd43d?x-bce-process=image/resize,m_fill,w_732,h_272'}
# 女子10米跳台决赛
# {'title': '女子10米跳台决赛', 'score': '468万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//bf6522444121bc8bf9afc968135414a2?x-bce-process=image/resize,m_fill,w_732,h_272'}
# {'title': '女子10米跳台决赛', 'score': '468万', 'imgurl': 'https://ss0.baidu.com/6ONWsjip0QIZ8tyhnq/it/u=3310461438,2025055068&fm=179&app=35&f=GIF?w=124&h=32&s=EEE3A256EC4383301C9B9FFA0300D03D'}
# 全红婵惊艳一跳裁判一致打满分
# {'title': '全红婵惊艳一跳裁判一致打满分', 'score': '460万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//0c6a1466b0751186ddf4d04ae71cb971?x-bce-process=image/resize,m_fill,w_732,h_272'}
# 监狱拍视频介绍高墙内的世界
# {'title': '监狱拍视频介绍高墙内的世界', 'score': '445万', 'imgurl': 'https://fyb-1.cdn.bcebos.com/fyb-1//dff7d35068d63af27cb5ae8d7874c3ff?x-bce-process=image/resize,m_fill,w_732,h_272'}
# 美媒边说奖牌不重要边嘲讽印度
# ...

# %%
categories =[
        {
            name:'类别A',
            itemStyle:{
                color:'#f44336'
            }
        },{
            name:'类别B',
            itemStyle:{
                color:'#e91e63'
            }
        },{
            name:'类别C',
            itemStyle:{
                color:'#9c27b0'
            }
        },{
            name:'类别D',
            itemStyle:{
                color:'#673ab7'
            }
        },
        {
            name:'类别E',
            itemStyle:{
                color:'#3f51b5'
            }
        },
        {
            name:'类别F',
            itemStyle:{
                color:'#ff9800'
            }
        },{
            name:'类别G',
            itemStyle:{
                color:'#8bc34a'
            }
        }]

# %%
import requests
def download_img(img_url,file_path='test.png'):
#     print (img_url)
    r = requests.get(img_url, stream=True)
#     print(r.status_code) # 返回状态码
    if r.status_code == 200:
        open(file_path, 'wb').write(r.content) # 将内容写入图片
        print("done")
    del r

# %%
download_img(url,file_path)

# %%
hots=[
    {
        "title": "31省区市新增62例本土确诊",
        "score": "500万",
        "imgurl": "https://fyb-1.cdn.bcebos.com/fyb-1//2818645318b88b0f1e6d5c6a073dd43d?x-bce-process=image/resize,m_fill,w_732,h_272",
        "color": [
            [
                14,
                181,
                211
            ],
            [
                205,
                233,
                243
            ],
            [
                19,
                147,
                206
            ],
            [
                16,
                112,
                204
            ],
            [
                7,
                85,
                195
            ],
            [
                40,
                111,
                159
            ],
            [
                36,
                139,
                169
            ]
        ]
    },
    {
        "title": "女子10米跳台决赛",
        "score": "468万",
        "imgurl": "https://fyb-1.cdn.bcebos.com/fyb-1//bf6522444121bc8bf9afc968135414a2?x-bce-process=image/resize,m_fill,w_732,h_272",
        "color": [
            [
                219,
                188,
                180
            ],
            [
                167,
                28,
                49
            ],
            [
                4,
                5,
                10
            ],
            [
                49,
                27,
                29
            ],
            [
                70,
                78,
                84
            ],
            [
                16,
                20,
                21
            ],
            [
                60,
                58,
                68
            ]
        ]
    },
    {
        "title": "女子10米跳台决赛",
        "score": "468万",
        "imgurl": "https://ss0.baidu.com/6ONWsjip0QIZ8tyhnq/it/u=3310461438,2025055068&fm=179&app=35&f=GIF?w=124&h=32&s=EEE3A256EC4383301C9B9FFA0300D03D",
        "color": [
            [
                252,
                100,
                100
            ]
        ]
    },
    {
        "title": "全红婵惊艳一跳裁判一致打满分",
        "score": "460万",
        "imgurl": "https://fyb-1.cdn.bcebos.com/fyb-1//0c6a1466b0751186ddf4d04ae71cb971?x-bce-process=image/resize,m_fill,w_732,h_272",
        "color": [
            [
                207,
                158,
                137
            ],
            [
                7,
                9,
                24
            ],
            [
                140,
                79,
                66
            ],
            [
                31,
                80,
                153
            ],
            [
                65,
                61,
                57
            ],
            [
                63,
                33,
                24
            ],
            [
                36,
                204,
                36
            ]
        ]
    },
    {
        "title": "监狱拍视频介绍高墙内的世界",
        "score": "445万",
        "imgurl": "https://fyb-1.cdn.bcebos.com/fyb-1//dff7d35068d63af27cb5ae8d7874c3ff?x-bce-process=image/resize,m_fill,w_732,h_272",
        "color": [
            [
                149,
                149,
                146
            ],
            [
                8,
                10,
                16
            ],
            [
                43,
                40,
                45
            ],
            [
                90,
                85,
                93
            ],
            [
                43,
                49,
                104
            ],
            [
                72,
                78,
                111
            ],
            [
                100,
                100,
                91
            ]
        ]
    },
    {
        "title": "美媒边说奖牌不重要边嘲讽印度",
        "score": "436万",
        "imgurl": "https://fyb-1.cdn.bcebos.com/fyb-1//b2b3c3c11da9e7d53c7a403b25dc5fc2?x-bce-process=image/resize,m_fill,w_732,h_272",
        "color": [
            [
                225,
                207,
                175
            ],
            [
                4,
                4,
                4
            ],
            [
                113,
                87,
                62
            ],
            [
                36,
                42,
                82
            ],
            [
                48,
                71,
                154
            ],
            [
                29,
                29,
                45
            ],
            [
                64,
                45,
                33
            ]
        ]
    },
    {
        "title": "苏炳添谢震业太好笑了",
        "score": "421万",
        "imgurl": "https://fyb-1.cdn.bcebos.com/fyb-1//a6b7bfdb225a16c9825468a8337401e5?x-bce-process=image/resize,m_fill,w_732,h_272",
        "color": [
            [
                61,
                33,
                43
            ],
            [
                198,
                180,
                190
            ],
            [
                164,
                98,
                78
            ],
            [
                192,
                15,
                44
            ],
            [
                156,
                113,
                123
            ],
            [
                122,
                32,
                37
            ],
            [
                185,
                55,
                86
            ]
        ]
    },
    {
        "title": "湖南一家16口超级大家庭居家隔离",
        "score": "417万",
        "imgurl": "https://fyb-1.cdn.bcebos.com/fyb-1//3931ba98db2119526c6f28dacd4f27e8?x-bce-process=image/resize,m_fill,w_732,h_272",
        "color": [
            [
                223,
                226,
                226
            ],
            [
                60,
                57,
                51
            ],
            [
                108,
                76,
                39
            ],
            [
                135,
                138,
                136
            ],
            [
                127,
                108,
                89
            ],
            [
                169,
                154,
                144
            ],
            [
                185,
                180,
                156
            ]
        ]
    },
    {
        "title": "呼伦贝尔市报告1例本土确诊病例",
        "score": "409万",
        "imgurl": "https://fyb-1.cdn.bcebos.com/fyb-1//2818645318b88b0f1e6d5c6a073dd43d?x-bce-process=image/resize,m_fill,w_732,h_272",
        "color": [
            [
                14,
                181,
                211
            ],
            [
                205,
                233,
                243
            ],
            [
                19,
                147,
                206
            ],
            [
                16,
                112,
                204
            ],
            [
                7,
                85,
                195
            ],
            [
                40,
                111,
                159
            ],
            [
                36,
                139,
                169
            ]
        ]
    },
    {
        "title": "外交部回应美国务院批准对台军售",
        "score": "398万",
        "imgurl": "https://fyb-1.cdn.bcebos.com/fyb-1//3ae25885178497fc6d03238270342d79?x-bce-process=image/resize,m_fill,w_732,h_272",
        "color": [
            [
                143,
                138,
                128
            ],
            [
                195,
                193,
                186
            ],
            [
                48,
                47,
                49
            ],
            [
                105,
                98,
                84
            ],
            [
                148,
                154,
                165
            ],
            [
                96,
                99,
                104
            ],
            [
                108,
                99,
                102
            ]
        ]
    },
    {
        "title": "全国上半年离婚大数据:河南最多",
        "score": "381万",
        "imgurl": "https://fyb-1.cdn.bcebos.com/fyb-1//98882b33a040f97045fc0cec4dd68458?x-bce-process=image/resize,m_fill,w_732,h_272",
        "color": [
            [
                218,
                216,
                216
            ],
            [
                134,
                50,
                59
            ],
            [
                175,
                136,
                141
            ],
            [
                152,
                101,
                107
            ],
            [
                72,
                59,
                54
            ],
            [
                115,
                104,
                101
            ],
            [
                141,
                81,
                94
            ]
        ]
    }
]

# %%
colors =[[244,67,54],[233,30,99],[156,39,176],[103,58,183],[63,81,181],[255,152,0],[139,195,74]]

# %%
#使用scikit learn的余弦相似度计算方法 demo
from sklearn.metrics.pairwise import cosine_similarity

#从target_colors得到与color最近的颜色,用于分类颜色
# rgb空间比hsv来计算更为准确
def get_target_color(color):
    # 颜色分类，简化版
    target_colors=[[244,67,54],[233,30,99],[156,39,176],[103,58,183],[63,81,181],[255,152,0],[139,195,74]]
    sim=cosine_similarity([color]+target_colors)
    index=np.argmax(sim[0][1:-1])
    target=target_colors[index]
    return target

tc=get_target_color([52,146,206])

out = Image.new("RGB", (100, 100), (255, 255, 255))
d = ImageDraw.Draw(out)
print(tc)
d.rectangle(((0, 0), (100, 100)), fill=(tc[0],tc[1],tc[2]))
out.show()
# Out:
# [63, 81, 181]
